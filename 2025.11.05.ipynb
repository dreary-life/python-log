# %% [markdown]
# <a href="https://colab.research.google.com/github/dreary-life/python-log/blob/main/2025.11.05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **표준 라이브러리**
# ---
# *datetime.date*
# ---
# 연,월,일 날짜를 표현할 때 사용하는 함수이고, 주로 사용되는 경우:
#
# 1. 현재 시간과 날짜를 구할 때
# 2. 날짜의 차이를 구할 때
# 3. 특정 날짜의 요일을 구할 때
#
#
#
# ```
# #기초 예제
# import datetime
#
# #현재 시간을 구하기
# print(datetime.datetime.now())
#
# #날짜의 차이를 구하기
# day1 = datetime.date(2004, 4, 18)
# day2 = datetime.date(2025, 11, 15)
# diff= day2 - day1
# print(diff.days)
#
# #요일 구하기
# day= datetime.date(2025, 11, 5)
# print(day.weekday())
# ```
# 1.현재시간 : 2025-11-05 08:35:47.875274
# 2.날짜의 차이 : 7881
# 3.요일 : 2

# %% [markdown]
# *time*
# ---
# time 모듈에는 함수가 매우 많음
# 1. time.time
# 2. time.loclatime
# 3. time.asctime
# 4. time.ctime
# 5. time.strftime
# 6. time.sleep
#
#
# ```
# #기초 예제
# import time
#
# #1970년 1월 1일 0시 0분 0초를 기준으로 지난 시간을 초 단위로 리턴해줌
# print(time.time())
#
# #time.time()이 리턴한 실숫값을 사용해서 연,월,일,시,분,초, ...의 형태로 바꾸어줌
# print(time.localtime(time.time()))
#
# #time.localtime이 리턴된 튜플 형태의 값을 보기 좋게 리턴
# print(time.asctime(time.localtime(time.time())))
#
# #time.asctime()을 간단하게 표시(asctime과 다른점은 현재 시간만 리턴)
# print(time.ctime())
#
# #strftime 함수는 시간과 관계된 것을 세밀하게 표현하는 여러 포맷 코드를 제공함
# #

# %% [markdown]
# # 새 섹션

# %%
import time
time.strftime('%a', time.ctime()
# Out:
#   File "/tmp/ipython-input-3263324234.py", line 2
#     time.strftime('%a', time.ctime()
#                                     ^
# SyntaxError: incomplete input
